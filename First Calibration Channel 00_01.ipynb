# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
reference_list = [2510, 2501, 2502, 2518, 2525, 2591, 2538, 2484, 2440, 2443, 2509, 2536, 2462, 2641, 2539, 2641, 2634, 2521, 2601, 2538, 2690, 2451, 2584, 2589, 2609, 2573, 2480, 2469]
single_list = [468, 574, 707, 802, 860, 936, 1032, 1127, 1195, 1248, 1449, 1522, 1656, 1901, 1956, 2266, 2410, 2603, 2884, 3199, 3561, 3780, 4078, 4609, 4920, 5569, 5948,6658]
coinc_list = [346,  435, 490, 567, 604, 620, 656, 665, 698, 651, 727, 679, 704, 755, 693, 718, 736, 727, 731, 756, 775, 686, 725, 723, 767, 764, 745, 774]

x_points = np.arange(0.6, 0.9, 0.01)
y_points = np.arange(0, 3050, 50)

#plt.scatter(reference_list, single_list)
#plt.scatter(coinc_list, single_list)
#plt.scatter(reference_list, coinc_list)

plt.scatter(single_list, reference_list, c = "blue")
plt.scatter(single_list, coinc_list, c = "red", marker = "*")
plt.scatter(coinc_list, reference_list, c = "grey")
