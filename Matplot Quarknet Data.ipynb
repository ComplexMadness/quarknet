# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1.2,1.21,1.22,1.23,1.3,1.4,1.45,1.46,1.47,1.48,1.49,1.5
],[1593.897425
,1654.373295
,1716.202494
,1774.417933
,2079.708633
,2326.150253
,2373.909013
,2384.89895
,2388.760348
,2390.485097
,2392.849139
,2393.911026
], marker = "*", markersize = 8)

plt.xlabel("Voltage Ch2")
plt.ylabel("Sigma 1")
plt.show()

# %%
x = [0.8,0.9,1,1.1,1.2,1.3,1.4,1.5]
y = [858.3932665,4665.927239
,7763.306383
,9217.919017
,9428.59926
,9725.514742
,10233.45577
,10399.70009
]

plt.plot(x,y,marker = "*",markersize=8)
plt.xlabel("Voltage Ch3 Retest")
plt.ylabel("Sigma 1")
plt.show()
